# %% [markdown]
# # Sample Run
# Minimal example of running the SAR preprocessing pipeline.

# %%
from preprocess_sar import preprocess
wkt_roi = None  # or set a POLYGON WKT string
preprocess('path/to/input.h5', wkt_roi)
